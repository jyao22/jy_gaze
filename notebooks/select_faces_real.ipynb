# %%
from pathlib import Path
import numpy as np
from PIL import Image

# %%
# !ls ../data/Label
# Out:
# p00.label  p03.label  p06.label  p09.label  p12.label
# p01.label  p04.label  p07.label  p10.label  p13.label
# p02.label  p05.label  p08.label  p11.label  p14.label

# %%
ipath = Path('../data/Image/')
rlabelpath = Path('../data/Label')

# %%
def check_good(pitch, yaw, p, y):
    if abs(pitch-p)<0.5 and abs(yaw-y) <0.5:
        return True
    else:
        return False

# %%
nf =0
for rlfile in rlabelpath.glob('*.label'):
    nf += 1
#     if nf >2:
#         break
    with open(rlfile) as rf:
        lines = rf.readlines()
        for line in lines[1:]:
            gaze2d = line.strip().split(" ")[7]
            face = line.strip().split(" ")[0]
            label = np.array(gaze2d.split(",")).astype("float")
            pitch = label[0]* 180 / np.pi
            yaw = label[1]* 180 / np.pi
            if check_good(pitch, yaw, 0, 3):
#                 print(line)
                ifile = ipath/face
                print(pitch, yaw, face, ifile)
# Out:
# -0.03634836643631331 3.4190410710697114 p14/face/253.jpg ../data/Image/p14/face/253.jpg
# -0.18755095946510172 3.4037863742306653 p14/face/796.jpg ../data/Image/p14/face/796.jpg
# 0.4314477746343312 2.612551611238401 p14/face/1482.jpg ../data/Image/p14/face/1482.jpg
# 0.03634836643631331 3.4190410710697114 p14/face/1836.jpg ../data/Image/p14/face/1836.jpg
# 0.18755095946510172 3.4037863742306653 p14/face/2056.jpg ../data/Image/p14/face/2056.jpg
# -0.4314477746343312 2.612551611238401 p14/face/2652.jpg ../data/Image/p14/face/2652.jpg

# %%
# pitch = -10, yaw = 0)
ifile = Path('../data/Image/p02/face/30.jpg')
im = Image.open(ifile)
im.show(0)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
# (pitch=10, yaw = 0)
ifile = Path('../data/Image/p02/face/395.jpg')
im = Image.open(ifile)
im.show(0)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
# (pitch=0, yaw = -10)
ifile = Path('../data/Image/p02/face/1057.jpg')
im = Image.open(ifile)
im.show(0)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
# (pitch=0, yaw = 3.4)
ifile = Path('../data/Image/p14/face/253.jpg')
im = Image.open(ifile)
im.show(0)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
ipath = Path('../data/sdata/Image/')
rlabelpath = Path('../data/sdata/Label')

# %%
nf =0
for rlfile in rlabelpath.glob('*.label'):
    nf += 1
#     if nf >2:
#         break
    with open(rlfile) as rf:
        lines = rf.readlines()
        for line in lines[1:]:
            gaze2d = line.strip().split(" ")[7]
            face = line.strip().split(" ")[0]
            label = np.array(gaze2d.split(",")).astype("float")
            pitch = label[0]* 180 / np.pi
            yaw = label[1]* 180 / np.pi
            if check_good(pitch, yaw, 0, -10):
#                 print(line)
                ifile = ipath/face
                print(pitch, yaw, face, ifile)
# Out:
# -0.17804116010665894 -10.267477035522461 face/fold02/990.jpeg ../data/sdata/Image/face/fold02/990.jpeg
# 0.45327162742614746 -10.062649726867676 face/fold02/1708.jpeg ../data/sdata/Image/face/fold02/1708.jpeg
# 0.39712855219841003 -9.510394096374512 face/fold11/1177.jpeg ../data/sdata/Image/face/fold11/1177.jpeg
