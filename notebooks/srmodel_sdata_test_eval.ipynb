# %%
# this is to find problem pics

# %%
import os, argparse
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from pytz import timezone
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
import torch.backends.cudnn as cudnn
import torchvision
import wandb

import datasets
# from utils import select_device, natural_keys, gazeto3d, angular, getArch
from utils import select_device, natural_keys, gazeto3d, angular, getArch
from model import L2CS

# %%
wandb.init(project="smode_rdata")
# Out:
# wandb: Currently logged in as: synthesis-ai (use `wandb login --relogin` to force relogin)
# wandb version 0.12.18 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/project/notebooks/wandb/run-20220616_203428-sxczehqr</code>
# Syncing run <strong><a href="https://wandb.ai/synthesis-ai/smode_rdata/runs/sxczehqr" target="_blank">efficient-dragon-7</a></strong> to <a href="https://wandb.ai/synthesis-ai/smode_rdata" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/synthesis-ai/smode_rdata/runs/sxczehqr?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
# check if we have the correct number of checkpoint files 
ppath ='/project/results/output/snapshots/' 
for fold in range(15):
    foldstr = f"fold{fold:0>2}"
    cpath =os.path.join(ppath, foldstr)
    files = os.listdir(cpath)
    print(len(files), end=" ")
# Out:
# 61 61 61 61 61 61 61 61 61 61 61 61 61 61 61

# %%
def parse_args():
    """Parse input arguments."""
    parser = argparse.ArgumentParser(
        description='Gaze estimation using L2CSNet .')
     # Gaze360
    parser.add_argument(
        '--gaze360image_dir', dest='gaze360image_dir', help='Directory path for gaze images.',
        default='datasets/Gaze360/Image', type=str)
    parser.add_argument(
        '--gaze360label_dir', dest='gaze360label_dir', help='Directory path for gaze labels.',
        default='datasets/Gaze360/Label/test.label', type=str)
    # mpiigaze
    parser.add_argument(
        '--gazeMpiimage_dir', dest='gazeMpiimage_dir', help='Directory path for gaze images.',
        default='datasets/MPIIFaceGaze/Image', type=str)
    parser.add_argument(
        '--gazeMpiilabel_dir', dest='gazeMpiilabel_dir', help='Directory path for gaze labels.',
        default='datasets/MPIIFaceGaze/Label', type=str)
    # Important args -------------------------------------------------------------------------------------------------------
    # ----------------------------------------------------------------------------------------------------------------------
    parser.add_argument(
        '--dataset', dest='dataset', help='gaze360, mpiigaze',
        default= "gaze360", type=str)
    parser.add_argument(
        '--snapshot', dest='snapshot', help='Path to the folder contains models.', 
        default='output/snapshots/L2CS-gaze360-_loader-180-4-lr', type=str)
    parser.add_argument(
        '--evalpath', dest='evalpath', help='path for the output evaluating gaze test.',
        default="evaluation/L2CS-gaze360-_loader-180-4-lr", type=str)
    parser.add_argument(
        '--gpu',dest='gpu_id', help='GPU device id to use [0]',
        default="0", type=str)
    parser.add_argument(
        '--batch_size', dest='batch_size', help='Batch size.',
        default=100, type=int)
    parser.add_argument(
        '--arch', dest='arch', help='Network architecture, can be: ResNet18, ResNet34, [ResNet50], ''ResNet101, ResNet152, Squeezenet_1_0, Squeezenet_1_1, MobileNetV2',
        default='ResNet50', type=str)
    # ---------------------------------------------------------------------------------------------------------------------
    # Important args ------------------------------------------------------------------------------------------------------
    args = parser.parse_args()
    return args

# %%
class Nothing:
    pass
args = Nothing()
args.gazeMpiimage_dir = '/project/data/sdata/Image'  #real data 
args.gazeMpiilabel_dir = '/project/data/sdata/Label'  #real label
args.output = '/project/results/output/snapshots/'  #real data model
args.dataset = 'mpiigaze'
args.snapshot='/project/results/output/snapshots/'  #real data snapshots
args.evalpath = '/project/results/rsoutput/evaluation/'
args.gpu_id = '0,1,2,3'
args.gpu_id = '0'
args.batch_size = 20
args.arch = 'ResNet50'
args.bins=28
args.angle = 180
args.bin_width = 4

# %%
batch_size=args.batch_size
arch=args.arch
data_set=args.dataset
evalpath =args.evalpath
snapshot_path = args.snapshot
bins=args.bins
angle=args.angle
bin_width=args.bin_width

# %%
# args = parse_args()
cudnn.enabled = True
gpu = select_device(args.gpu_id, batch_size=args.batch_size)
transformations = transforms.Compose([
    transforms.Resize(448),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

model_used=getArch(arch, bins)  #resnet50 and 28 bins

# %%
# fold=2
# folder = os.listdir(os.path.join(snapshot_path, "fold" + f'{fold:0>2}'))
# folder.sort(key=natural_keys)
# folder.pop(-1)  #remove the tensorboard file
# # print(folder)
# epochs = folder[3]
# os.path.join(snapshot_path+"fold"+f'{fold:0>2}', epochs)

# %%
# print(evalpath, snapshot_path)

# %%
# print(data_set)

# %%
# %%time
all_MAE = []
# tosave={}
for fold in range(15):
    print(f"{fold={fold}")
    epoch_values=[]
    mae_values=[]
    
    now = datetime.utcnow()
    now = now.astimezone(timezone('US/Pacific'))
    date_format='%m/%d/%Y %H:%M:%S'
    now = now.strftime(date_format)
    
    print(args.gazeMpiilabel_dir)
    folder = os.listdir(args.gazeMpiilabel_dir)
    folder.sort()  #individual label files
    testlabelpathcombined = [os.path.join(args.gazeMpiilabel_dir, j) for j in folder] 
    
    gaze_dataset=datasets.Mpiigaze(testlabelpathcombined, args.gazeMpiimage_dir, transformations, False, angle, fold)

    test_loader = torch.utils.data.DataLoader(
        dataset=gaze_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=4,
        pin_memory=True)

    fold_path = os.path.join(evalpath, 'fold' + f'{fold:0>2}'+'/')  #for evaluation
#     print(f"fold_path is {fold_path}")
    if not os.path.exists(fold_path):
        os.makedirs(fold_path)

#     if not os.path.exists(os.path.join(evalpath, f"fold"+str(fold))):
#         os.makedirs(os.path.join(evalpath, f"fold"+str(fold)))

    # list all epoch for testing
    folder = os.listdir(os.path.join(snapshot_path, "fold" + f'{fold:0>2}'))
    folder.sort(key=natural_keys)
    folder.pop(-1)  #remove the tensorboard file, now all snapshot files
#     print(f"folder={folder}")
                    

    softmax = nn.Softmax(dim=1)
#     with open(os.path.join(evalpath, os.path.join("fold"+f'{fold:0>2}', data_set+".log")), 'w') as outfile:
        
    configuration = (f"\ntest configuration equal gpu_id={gpu}, batch_size={batch_size}, model_arch={arch}\n"
                     f"Start testing dataset={data_set}, FOLD={fold} --{now}---------")
#         print(configuration)
#     tosave['time':now]
#     outfile.write(configuration)
    epoch_list=[]
    avg_MAE=[]
    for epoch in folder: 
        print(f"entering epoch={epoch}")
        model=model_used
        checkpoint = torch.load(os.path.join(snapshot_path+"fold"+f'{fold:0>2}', epoch))
        saved_state_dict = checkpoint['model_state_dict']
        model= nn.DataParallel(model,device_ids=[0])
        model.load_state_dict(saved_state_dict)
        model.cuda(gpu)
        model.eval()
        total = 0
        idx_tensor = [idx for idx in range(28)]
        idx_tensor = torch.FloatTensor(idx_tensor).cuda(gpu)
        avg_error = .0
        with torch.no_grad():
            for j, (images, labels, cont_labels, name) in enumerate(test_loader):
                images = Variable(images).cuda(gpu)
                total += cont_labels.size(0)

                label_pitch = cont_labels[:,0].float()*np.pi/180
                label_yaw = cont_labels[:,1].float()*np.pi/180

                gaze_pitch, gaze_yaw = model(images)

                # Binned predictions
                _, pitch_bpred = torch.max(gaze_pitch.data, 1)
                _, yaw_bpred = torch.max(gaze_yaw.data, 1)

                # Continuous predictions
                pitch_predicted = softmax(gaze_pitch)
                yaw_predicted = softmax(gaze_yaw)

                # mapping from binned (0 to 28) to angels (-42 to 42)                
                pitch_predicted = \
                    torch.sum(pitch_predicted * idx_tensor, 1).cpu() * 3 - 42
                yaw_predicted = \
                    torch.sum(yaw_predicted * idx_tensor, 1).cpu() * 3 - 42

                pitch_predicted = pitch_predicted*np.pi/180
                yaw_predicted = yaw_predicted*np.pi/180

                for p,y,pl,yl in zip(pitch_predicted, yaw_predicted, label_pitch, label_yaw):
                    avg_error += angular(gazeto3d([p,y]), gazeto3d([pl,yl]))

        x = ''.join(filter(lambda i: i.isdigit(), epoch))
#             print(f"x={x}")
        epoch_list.append(x)
        mean_mae = avg_error/total  #mean mae over the 3000 iamges
        avg_MAE.append(mean_mae)  
#             print(f"total={total}")
        
        loger = f"[{epoch}---{args.dataset}] Total Num:{total},MAE:{mean_mae}"
#         outfile.write(loger)
        print(loger)
#             print(f"done epoch={epochs}")
        epochn = int(x)
#         wandb.log({'epoch':epochn,'total':total, 'MAE':mean_mae, 'FOLD':fold })
#         tosave ={'epoch':epochn,'total':total, 'MAE':mean_mae, 'FOLD':fold }
        epoch_values.append(epochn)
        mae_values.append(mean_mae)
# #         wandb.log(tosave)
    all_MAE.append(avg_MAE)
    data = [[x, y] for (x, y) in zip(epoch_values, mae_values)]
    table = wandb.Table(data=data, columns = ["x", "y"])
    wandb.log({"epoch_losses" : wandb.plot.line(table, "x", "y",
               title="Epoch loss for each fold")})
    
#     fig = plt.figure(figsize=(14, 8))        
#     plt.xlabel('epoch')
#     plt.ylabel('avg')
#     plt.title('Gaze angular error')
#     plt.legend()
#     plt.plot(epoch_list, avg_MAE, color='k', label='mae')
#     fig.savefig(os.path.join(evalpath, os.path.join("fold"+f'{fold:0>2}', data_set+".png")), format='png')
#     # plt.show()
# Out:
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:13.443461294262843
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:13.272026728035604
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:13.05084913579883
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:13.215686498409612
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:14.751142108376152
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:14.505299525619902
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:13.462039524435633
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:12.960322281379447
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:14.295336065145978
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:14.111884437230035
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:13.3698596631153
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:13.477886476203437
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:13.476284978493661
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:13.647971194144981
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:14.216706010927918
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:13.443234061010665
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:13.763733840013144
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:12.872190950921262
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:13.001318976258412
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:13.288370305243179
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:13.710464331399084
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:13.7618732923156
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:13.207286839886962
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:13.93288399937688
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:13.149730957152673
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:13.227092454916546
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:13.592363279057222
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:13.165388869030016
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:13.663443957881048
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:13.155663942111028
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:13.819876133956674
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:13.715367971620479
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:13.317292859684636
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:13.760092195851517
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:13.806157290481092
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:13.590291079461453
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:13.347339734078833
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:13.848463782668833
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:13.520485971795424
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:13.530597953504097
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:13.580026456644822
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:13.573854837056142
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:13.204260932216533
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:13.51461806353243
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:13.662298316362746
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:13.218932890409254
# entering epoch=epoch_47.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:13.00044567203749
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:13.440450364094476
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:13.563485292766789
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:13.547306968414121
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:13.583415496753338
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:13.165242165370431
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:14.037832847545312
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:10.491782251983638
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:11.826527908313476
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:11.780701726135181
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:11.718030159374605
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:13.575573587246557
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:12.673603517109935
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:13.081318319716427
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:12.349906017005873
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:12.794165041243033
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:13.000398233686564
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:12.449115066395454
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:12.690644585247293
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:12.926961970309822
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:12.60655600583221
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:13.111087324425934
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:13.09031421243816
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:12.929091331910591
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:13.01788115231037
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:12.667664137831268
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:13.515197835624782
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:13.547587442507922
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:13.206085415713531
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:13.031231595362271
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:12.648365188482638
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:13.04050719097006
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:12.090106166433728
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:12.993938191612699
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:12.61592282737934
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:13.164756852505326
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:12.49226930844752
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:12.77701899281728
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:12.413398196990068
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:12.355726260900624
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:11.836679627708811
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:13.25995190078653
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:12.405906232419197
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:13.12468012015193
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:12.36502243007355
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:12.129889539532288
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:13.006008781154232
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:12.14798033160813
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:13.112901735668938
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:12.447884594604478
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:12.855781541459212
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:13.045245425648451
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:13.506203148067017
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:12.786477747096797
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:13.14844662552312
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:14.127415419952621
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:12.561382342495381
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:13.638866780304296
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:13.39809269367519
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:12.28785865518478
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:13.06531372435325
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:13.13316077243291
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:12.682043599676453
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:13.523953736205689
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:13.286109689753209
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:12.820354368661395
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:13.383214914550086
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:13.437582086305563
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:11.906559140140596
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:12.170477988943427
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:11.656649612483896
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:12.042621339220634
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:11.719676831480536
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:12.767497433114663
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:12.130660819019598
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:12.243651291329797
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:12.771391862357863
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:12.23047638593048
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:12.334211080903005
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:12.155129367191963
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:12.438258408157411
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:12.330979681491582
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:13.027666188292315
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:12.807220988519825
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:12.719162907417681
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:12.272775064604456
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:11.933102787511368
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:12.651511568164755
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:12.645179181300664
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:12.69118894740587
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:12.24210128503672
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:12.31821679560572
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:12.627969850019817
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:12.487961948492615
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:12.332524108347913
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:12.498152707594246
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:12.394662012944217
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:12.436574660004261
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:12.7040142761227
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:12.863660011722116
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:12.63506295013424
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:12.744000651598908
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:12.530544623837956
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:12.146520822525599
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:12.678876690192297
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:12.476096501546737
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:12.685545259365535
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:12.648437811919141
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:12.818563839699813
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:12.16592393323301
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:13.205085529329015
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:13.202356019198513
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:12.91883051485166
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:12.799562953165031
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:12.870549232971124
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:12.476336318214882
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:12.79303251313183
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:13.560346746882589
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:13.238479329697439
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:12.621799786812298
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:13.230814187609974
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:13.21326946879756
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:13.104895980250872
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:13.515634020175595
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:13.606973218754339
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:13.40483263547231
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:13.51532795920574
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:14.950227749730537
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:13.80032379716777
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:14.50772061217118
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:15.327281892632193
# entering epoch=epoch_5.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:16.793003724939275
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:15.606346300982707
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:15.119389624180405
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:15.636851413767198
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:16.3140124059663
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:16.146819446768184
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:16.295863933331184
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:16.1025489243627
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:16.264760520692807
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:16.180656471924838
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:15.85501546172178
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:15.366116595455448
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:15.89586453570271
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:15.588454564544964
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:15.18770250711876
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:15.849573964435113
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:16.034085745701464
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:15.808662427088363
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:15.59191248232966
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:16.249472129296187
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:15.365570260912355
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:15.227509902888833
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:15.57249676172245
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:15.464012064023457
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:15.710017107363948
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:15.359910054824207
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:15.549122009716655
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:16.395240181946747
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:15.871291055122022
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:15.354820789572534
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:15.512029858078238
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:15.65901424340774
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:16.098432830341334
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:15.577935876441108
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:15.235840173044497
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:15.460963059575695
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:15.649908308067936
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:15.465911536730738
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:15.668918117529763
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:15.32924230156323
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:15.511065476850511
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:15.716784454344308
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:15.292516130059754
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:15.384712679754386
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:15.650299503185444
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:15.244961355252793
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:15.531493757991822
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:15.588418709524657
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:15.745313124630112
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:15.448613063291184
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:16.779046908069564
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:13.679675352910577
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:16.434874462337106
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:15.026861376278248
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:14.256720421743257
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:15.67762218109057
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:14.966332661035826
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:15.62498708752471
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:15.75743306440646
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:15.637361403476433
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:16.357555109083588
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:14.659201528973213
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:14.510188037169193
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:14.163761272679622
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:15.822249175775056
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:15.96855349495424
# entering epoch=epoch_18.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:14.115285708548742
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:13.95095161740725
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:14.309898091528902
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:13.784342361001714
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:14.647402233862886
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:14.10304308846454
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:14.937407653374054
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:15.442340644054093
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:14.958405194347714
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:15.072258131744803
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:14.838154799982789
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:14.685980651564938
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:14.557370232108267
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:14.308506139947706
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:14.518545393984889
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:13.925883076558064
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:14.349789423559026
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:14.271627814847903
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:14.618724510176326
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:14.68026591590772
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:14.209554651731786
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:14.394626589364826
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:14.791029315318864
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:14.38460914620323
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:14.8976672786169
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:14.658377313357686
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:14.664195020728252
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:14.220815957080788
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:14.554654071274756
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:14.657063695186382
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:14.719934317069875
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:15.08148838872941
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:14.575834969473318
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:14.681635808221653
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:14.508934262609595
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:14.25644033702224
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:13.984823247369034
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:17.964203021855834
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:15.932887312284759
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:15.131474181508189
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:15.675572341712451
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:15.501681880287242
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:14.65556632889195
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:16.27558682478298
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:14.818206509441154
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:15.631081950697125
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:14.313279221694602
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:15.7172777898712
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:16.055865112434002
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:15.060931777422937
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:15.309816568501102
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:14.651345622142339
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:14.619369356585377
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:15.910627771604515
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:14.40378493071858
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:16.374388526945975
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:14.981947667337165
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:14.675340204189927
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:14.473831544103234
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:14.803503160001153
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:15.019893992275383
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:14.261690703462536
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:15.331490078806826
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:15.336795443830608
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:15.409247878383646
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:15.110562571446193
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:15.096430766051128
# entering epoch=epoch_31.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:15.041573668884848
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:14.943737776587065
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:14.603268262940778
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:14.35392906315127
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:14.688988071220328
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:14.999728295054336
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:15.139248345368996
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:14.63752396569802
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:14.608401510485557
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:14.653101738309623
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:14.927507029198226
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:14.510700448009638
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:14.846380177736112
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:14.521242211223784
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:14.726563589915946
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:14.298675704005012
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:14.230993565485898
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:14.86722024082969
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:14.945457062399598
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:14.677432335264832
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:14.836142737426846
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:14.924039153212988
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:14.948955214592749
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:14.920167247066436
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:15.382952563532733
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:14.764686778172972
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:15.381200875941456
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:15.277646428139525
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:15.109161545996988
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:14.425066880546202
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:14.879260968250577
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:15.145225421895171
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:15.578658579035654
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:15.143335986041405
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:15.115607940247012
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:15.461323756200665
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:15.315652598508194
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:15.715317213235915
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:15.350457567907867
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:15.403106117400789
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:15.677350459203371
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:15.382465576755111
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:15.443636208719369
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:15.68345740616499
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:15.347518899031165
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:15.963000541224366
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:15.881658775509852
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:15.518838449869346
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:15.677812643453331
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:15.349558176732328
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:15.474000973519578
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:15.207026891675511
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:15.62788400601343
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:15.457767080339568
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:15.350576895679083
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:15.614274402491517
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:15.814549893331204
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:15.444099739703233
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:15.3270605245482
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:15.436291411022395
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:15.640412564185423
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:15.403418937168293
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:15.018677144803403
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:15.624967608631003
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:15.528348331396902
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:15.65953353214213
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:15.706230199183969
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:15.743534063241134
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:15.582826351113157
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:15.707134530950244
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:15.438001288728806
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:15.39213468911937
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:15.524120213445627
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:15.641531093312384
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:16.171468020890188
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:15.402648772509817
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:15.580065033128882
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:15.324733973867568
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:15.779001010512909
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:16.039602722930915
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:15.78652686521534
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:15.598790552661303
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:15.895613121128465
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:15.977495606676142
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:14.221325092890055
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:14.38750137243116
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:12.985790662157546
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:14.402741250349308
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:13.384009126601619
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:14.49003565647423
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:14.266491163571093
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:13.877659926985865
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:13.716506412513457
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:14.889558659570401
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:14.017537886616685
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:14.176028770092772
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:14.43772343052193
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:13.985355583212923
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:14.494313369396087
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:13.738218830191991
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:13.721496183275162
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:13.984773416572267
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:14.177004128097892
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:13.602446194308841
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:14.076637825245346
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:14.298076296387228
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:14.30166914716831
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:13.884453991784891
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:14.384852807476175
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:14.522525169936618
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:13.875764275291365
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:13.646857019486228
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:13.988895493856178
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:14.178209711632858
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:13.498843970135715
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:14.305283567795275
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:14.101484614994915
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:13.924476496820052
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:13.732052262120332
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:13.647584828270963
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:13.960522059087003
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:13.866402994772653
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:13.939148453310956
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:13.561644075498073
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:13.92716406445316
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:14.01540670028458
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:14.000697959876483
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:14.143837196734783
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:13.843685621972826
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:13.66839279199427
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:13.94329534801431
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:13.544693755224728
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:14.007031895880745
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:13.354894933252593
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:13.546235237391773
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:13.583538734283625
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:13.427248854184581
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:13.744825935843966
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:13.534249820090949
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:13.306292139460714
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:13.888512807284021
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:13.728339025250746
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:13.757047542549055
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:13.668745478948042
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:17.03426004621618
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:17.77801360113759
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:18.16116814351264
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:16.967382089197137
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:17.703716829813754
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:17.19379114835609
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:17.47081243499778
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:16.767995367823623
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:17.391177828687542
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:16.262132233846714
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:17.71950859582961
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:16.013620335728447
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:17.684267484303902
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:16.762354428576316
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:17.090507622224113
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:16.989615826950583
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:16.490750641223045
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:16.441591270690495
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:16.652512075549172
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:16.361121489020142
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:16.451455198293875
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:16.225908318872563
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:16.586184961039596
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:16.126101100570025
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:16.282198927988144
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:15.611856800331742
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:15.816010732272778
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:16.176786983396838
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:16.591101250644346
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:16.047940366587483
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:16.146047541959195
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:15.824217919872021
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:16.38786965146816
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:16.0713566624511
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:15.580416166475583
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:16.449198212528415
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:16.783226050728164
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:16.007642085679393
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:15.620999822232513
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:16.10974834815764
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:16.42756811872726
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:15.454755404367344
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:16.035535118939652
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:15.972859311917528
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:15.39007360820359
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:16.01947999579568
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:15.369476572119126
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:15.716995316776945
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:15.454401983779624
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:15.282041532153952
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:15.56156756288874
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:15.17992219297891
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:15.786569614960827
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:15.434513009753712
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:15.35960515194965
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:15.280802276335203
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:15.617771061807025
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:15.473637764198186
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:15.263623662139088
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:15.290902360417176
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:14.428234184103234
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:14.245346079821733
# entering epoch=epoch_3.pkl
# ...
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:15.459060970225813
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:15.275034634628792
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:15.323070222739785
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:15.312031094605405
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:15.39816725887699
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:14.908390604927291
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:11.977193586655108
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:12.797395813631418
# entering epoch=epoch_3.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:13.03211286923312
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:12.870489797404352
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:14.071039369634617
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:13.182245178223717
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:13.51337230359303
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:13.380277889874304
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:13.494278829400752
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:13.895411813780845
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:12.606358830218824
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:13.687348415762914
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:13.177646449998678
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:13.378084319356951
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:13.117064904130153
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:13.915942550752279
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:12.795620806086367
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:12.679764333056012
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:12.790046600306919
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:14.123887835976774
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:13.19609645001601
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:13.509032625813406
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:12.952924637763283
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:13.632001085330822
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:14.031429420069461
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:13.826299314467617
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:13.601884184376198
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:13.786196939000142
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:13.07758044251388
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:13.321796007917447
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:13.016529755447465
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:13.199232795741693
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:13.544440907157439
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:13.008509784015647
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:13.698591517599054
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:13.026432788418196
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:13.613006680596955
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:13.037074271535133
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:13.549838469314981
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:13.288338629966061
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:13.338715727435112
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:13.700917127472383
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:13.309515209559887
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:13.40716642895572
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:13.858857390511014
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:13.338874678171509
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:13.592654550420093
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:13.676838048174732
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:13.377917060096154
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:13.707603082023867
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:13.895770938691737
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:13.602086263612904
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:13.841388202325831
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:13.331443894024172
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:12.14369209209067
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:12.598289728723136
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:12.947472668173406
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:14.16295791118765
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:13.654756055486626
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:14.148314703333476
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:13.421186635361266
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:13.473619252497802
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:13.874696538398348
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:14.580439482123177
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:13.367840455594907
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:14.314582570293656
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:13.890264826091586
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:13.209498308234679
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:14.059213667623041
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:15.111533911280855
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:12.668858793917895
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:13.576839391217636
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:14.614697960830453
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:14.378770968521527
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:13.932325916389187
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:13.93692297212377
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:13.691642413551715
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:13.280825857486345
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:13.340058563465687
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:13.991522250369897
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:13.496994138398719
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:14.205818161327308
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:13.567366493557063
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:13.911980964858026
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:13.575572563367457
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:13.466536176850054
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:14.308072549893458
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:14.262508957111532
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:13.697257912917491
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:13.414945473133283
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:14.104978835525365
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:13.566452375319832
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:14.031160991616392
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:13.080200304298677
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:13.986878847207688
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:13.433370774693374
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:13.34636699240078
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:13.93520842682738
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:13.13377755441464
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:13.42841501844893
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:14.040036808438877
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:13.994403300932383
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:13.589320030439628
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:14.185796356544694
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:14.212259423389723
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:13.129036779824846
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:14.069645980093629
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:13.999208543935248
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:13.411143334328566
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:13.67955570745424
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:13.758606504918982
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:14.317842373820136
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:14.01510901779125
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:12.853215759902831
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:13.428993970032597
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:14.185144235490105
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:15.126608437758197
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:14.67818637844228
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:14.262939628872369
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:14.70019307835768
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:14.588452425716532
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:14.25625169797184
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:14.194520688702207
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:14.796489219664632
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:13.674865570283258
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:14.227972738995913
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:14.1926748896606
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:14.123538724667112
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:14.404212834270094
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:14.674366150464445
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:14.06420928490485
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:14.237934239125503
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:14.170997332534968
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:14.397290592052823
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:13.880541226690667
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:14.283333784638366
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:14.14881764987651
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:14.61868596511219
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:14.667807051143619
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:14.171849626608783
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:14.448532889017285
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:14.153732849045104
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:14.316216478862401
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:14.4320717042465
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:14.290394329307667
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:14.48462240429988
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:14.17533977915186
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:14.413156314990374
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:14.292026884130976
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:14.296944295122609
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:14.27843448166599
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:14.246978399553644
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:13.94300969878788
# entering epoch=epoch_41.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:14.507646089144552
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:14.295151664464504
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:14.4164783109259
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:14.242757344190391
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:14.082113543733792
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:14.33588601016773
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:14.380896298946121
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:14.358219530332441
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:14.397814452665392
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:14.157139968025163
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:14.388453403175783
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:14.233170095018023
# CPU times: user 2h 55min 30s, sys: 1h 8min 44s, total: 4h 4min 14s
# Wall time: 3h 34min 6s

# %%
all_MAE=np.array(all_MAE)

# %%
print(all_MAE.shape)
print(all_MAE.mean(axis=0))
print(all_MAE.mean(axis=1))
print(all_MAE.mean(axis=0).argmin()+1 ,all_MAE.mean(axis=0).min())
# Out:
# (15, 60)
# [13.94803401 14.12621199 13.87429765 14.28510734 14.52365314 14.26136898
#  14.72937786 14.41138492 14.6085134  14.40903828 14.74414477 14.65334247
#  14.47695917 14.42759779 14.6158625  14.64778402 14.70694968 14.33433888
#  14.38146837 14.54328737 14.6441113  14.35636946 14.5157564  14.26281949
#  14.21101515 14.22714451 14.3784224  14.34982691 14.38313223 14.26448504
#  14.34562468 14.23770554 14.3856845  14.26282735 14.37663472 14.16338009
#  14.29246139 14.21649813 14.10672231 14.33135179 14.18399642 14.29394944
#  14.2081887  14.29561731 14.27500562 14.25953762 14.16549394 14.20877727
#  14.35553398 14.11678406 14.37833955 14.31601183 14.09729345 14.28963468
#  14.36563507 14.26609289 14.42344366 14.40188922 14.29202992 14.40147921]
# [13.54034763 12.79600434 12.64661947 15.66326575 14.79024152 15.01233557
#  15.48823844 13.92143397 16.25341114 15.10532141 13.31095936 15.2777245
#  13.33585395 13.73430159 14.27779881]
# 3 13.874297651351478
