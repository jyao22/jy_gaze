# %%
# Use the best model for each checkpoint folder to test maes for all data folds

# %%
import sys
import os, argparse
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from pytz import timezone
from pathlib import Path
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
import torch.backends.cudnn as cudnn
import torchvision
import wandb

import datasets
# from utils import select_device, natural_keys, gazeto3d, angular, getArch
from utils import select_device, natural_keys, gazeto3d, angular, getArch
from model import L2CS
sys.path.append('/project/modules/jmodules')
from jutils import get_now

# %%
# !pwd
# Out:
# /project/notebooks/jnotebooks

# %%
# !nvidia-smi
# Out:
# Wed Jul 27 01:08:20 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  On   | 00000000:20:1D.0 Off |                    0 |
# | N/A   31C    P0    75W / 400W |   7752MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
def parse_args():
    """Parse input arguments."""
    parser = argparse.ArgumentParser(description='Gaze estimation using L2CSNet')
#     # Gaze360
#     parser.add_argument(
#         '--gaze360image_dir', dest='gaze360image_dir', help='Directory path for gaze images.',
#         default='datasets/Gaze360/Image', type=str)
#     parser.add_argument(
#         '--gaze360label_dir', dest='gaze360label_dir', help='Directory path for gaze labels.',
#         default='datasets/Gaze360/Label/train.label', type=str)
#     # mpiigaze
    parser.add_argument(
        '--gazeMpiimage_dir', dest='gazeMpiimage_dir', help='Directory path for gaze images.',
        default='/project/data/sdata3/Image', type=str)
    parser.add_argument(
        '--gazeMpiilabel_dir', dest='gazeMpiilabel_dir', help='Directory path for gaze labels.',
        default='/project/data/sdata3/Label', type=str)

    # Important args -------------------------------------------------------------------------------------------------------
    # ----------------------------------------------------------------------------------------------------------------------
    parser.add_argument(
        '--dataset', dest='dataset', help='mpiigaze, rtgene, gaze360, ethgaze',
        default= "mpiigaze", type=str)
    parser.add_argument(
        '--output', dest='output', help='Path of output models.',
        default='/project/results/soutput3/snapshots/', type=str)
    parser.add_argument(
        '--snapshot', dest='snapshot', help='Path of model snapshot.',
        default='/project/results/soutput3/snapshots/', type=str)
    parser.add_argument(
        '--gpu', dest='gpu_id', help='GPU device id to use [0] or multiple 0,1,2,3',
        default='0', type=str)
    parser.add_argument(
        '--evalpath', dest='evalpath', help='path to save the evaluation results',
        default='/project/results/soutput3/evaluation/', type=str)
    parser.add_argument(
        '--num_epochs', dest='num_epochs', help='Maximum number of training epochs.',
        default=60, type=int)
    parser.add_argument(
        '--batch_size', dest='batch_size', help='Batch size.',
        default=50, type=int)
    parser.add_argument(
        '--arch', dest='arch', help='Network architecture, can be: ResNet18, ResNet34, [ResNet50], ''ResNet101, ResNet152, Squeezenet_1_0, Squeezenet_1_1, MobileNetV2',
        default='ResNet50', type=str)
    parser.add_argument(
        '--alpha', dest='alpha', help='Regression loss coefficient.',
        default=1, type=float)
    parser.add_argument(
        '--lr', dest='lr', help='Base learning rate.',
        default=0.00001, type=float)
    parser.add_argument(
        '--bins', dest='bins', help='number of angle bins',
        default=28, type=int)
    parser.add_argument(
        '--angle', dest='angle', help='angle limit',
        default=180, type=int)
    parser.add_argument(
        '--bin_width', dest='bin_width', help='width of anlge bins',
        default=4, type=int)
    
    # ---------------------------------------------------------------------------------------------------------------------
    # Important args ------------------------------------------------------------------------------------------------------
    args = parser.parse_args(['--angle', '180'])
    return args

# %%
args=parse_args()

# %%
# actually used
batch_size=args.batch_size
arch=args.arch
data_set=args.dataset
# evalpath =args.evalpath
snapshot_path = args.snapshot
bins=args.bins
angle=args.angle
bin_width=args.bin_width
gazeMpiimage_dir = args.gazeMpiimage_dir
gazeMpiilabel_dir=args.gazeMpiilabel_dir

# %%
# args = parse_args()
cudnn.enabled = True
gpu = select_device(args.gpu_id, batch_size=args.batch_size)
transformations = transforms.Compose([
    transforms.Resize(448),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])
model_used= getArch(arch, bins)  #resnet50 and 28 bins

# %%
spath = Path(snapshot_path)
ckfiles =[]
for filename in sorted(spath.glob('*.pkl'), 
        key=lambda path: int(path.stem.rsplit("_", 1)[1])):
    ckfiles.append(filename)
print(f'number of checkpoint files: {len(ckfiles)}')
# Out:
# number of checkpoint files: 60

# %%
#labels
lfolder = os.listdir(gazeMpiilabel_dir)
lfolder.sort()  #individual label files
testlabelpathcombined = [os.path.join(gazeMpiilabel_dir, j) for j in lfolder]
gaze_dataset=datasets.Mpiigaze(testlabelpathcombined, gazeMpiimage_dir, transformations, False, angle, fold=-1)
# print(testlabelpathcombined)

model = model_used
model= nn.DataParallel(model,device_ids=[0])  #important to load state dict

wandb.init(project='70_smodel_sdata', name='model_errors')
for ckn, ckfile in enumerate(ckfiles):
    print(ckn+1, ckfile)
    checkpoint = torch.load(ckfile)
    saved_state_dict = checkpoint['model_state_dict']
    model.load_state_dict(saved_state_dict)
    model.cuda(gpu)
    model.eval()
    idx_tensor = [idx for idx in range(bins)]
    idx_tensor = torch.FloatTensor(idx_tensor).cuda(gpu)
    softmax = nn.Softmax(dim=1)
#     best_model_maes =[]  # error for each data fold
    test_loader = torch.utils.data.DataLoader(
            dataset=gaze_dataset,
            batch_size=batch_size,
            shuffle=True,
            num_workers=4,
            pin_memory=True)
    now = get_now()
    configuration = f"\ntest configuration: gpu_id={gpu}, batch_size={batch_size}\n"
    configuration += f"model_arch={arch} Start testing dataset={data_set}--{now}--\n"
    print(configuration)
    
    total = 0  
    avg_error = .0
    with torch.no_grad():
        for j, (images, labels, cont_labels, name) in enumerate(test_loader):
            images = Variable(images).cuda(gpu)
            total += cont_labels.size(0)  #number of labels/images

            label_pitch = cont_labels[:,0].float()*np.pi/180
            label_yaw = cont_labels[:,1].float()*np.pi/180

            gaze_pitch, gaze_yaw = model(images)

            # Binned predictions
            _, pitch_bpred = torch.max(gaze_pitch.data, 1)
            _, yaw_bpred = torch.max(gaze_yaw.data, 1)

            # Continuous predictions
            pitch_predicted = softmax(gaze_pitch)
            yaw_predicted = softmax(gaze_yaw)

            # mapping from binned (0 to 28) to angels (-42 to 42)                
            pitch_predicted = \
                torch.sum(pitch_predicted * idx_tensor, 1).cpu() * 3 - 42
            yaw_predicted = \
                torch.sum(yaw_predicted * idx_tensor, 1).cpu() * 3 - 42

            pitch_predicted = pitch_predicted*np.pi/180
            yaw_predicted = yaw_predicted*np.pi/180

            for p,y,pl,yl in zip(pitch_predicted, yaw_predicted, label_pitch, label_yaw):
#                 pl, yl = yl, pl*(-1.0)
                avg_error += angular(gazeto3d([p,y]), gazeto3d([pl,yl])) #accumulate over all batches

    mean_mae = avg_error/total  
    now = get_now()
    msg = f"Total Num images Checked:{total}, MAE:{mean_mae}  {now}"
#         outfile.write(loger)
    wandb.log({'Mean_MAE':mean_mae}, step=ckn+1)
    print(msg)
#     best_model_maes.append(mean_mae)
# Out:
# path=/project/data/sdata3/Label/test.label
# 0 items removed from dataset that have an angle > 180
# wandb: Currently logged in as: synthesis-ai (use `wandb login --relogin` to force relogin)
# wandb version 0.12.21 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/project/notebooks/jnotebooks/wandb/run-20220727_010824-3adk8ud6</code>
# Syncing run <strong><a href="https://wandb.ai/synthesis-ai/70_smodel_sdata/runs/3adk8ud6" target="_blank">model_errors</a></strong> to <a href="https://wandb.ai/synthesis-ai/70_smodel_sdata" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 1 /project/results/soutput3/snapshots/epoch_1.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:08:27--
#
# Total Num images Checked:42767, MAE:14.70631392477412  07/26/2022 18:10:21
# 2 /project/results/soutput3/snapshots/epoch_2.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:10:22--
#
# Total Num images Checked:42767, MAE:15.472439181979627  07/26/2022 18:12:04
# 3 /project/results/soutput3/snapshots/epoch_3.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:12:05--
#
# Total Num images Checked:42767, MAE:14.857065022666784  07/26/2022 18:13:36
# 4 /project/results/soutput3/snapshots/epoch_4.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:13:36--
#
# Total Num images Checked:42767, MAE:12.949309343853498  07/26/2022 18:15:02
# 5 /project/results/soutput3/snapshots/epoch_5.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:15:02--
#
# Total Num images Checked:42767, MAE:14.26727697971502  07/26/2022 18:16:27
# 6 /project/results/soutput3/snapshots/epoch_6.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:16:27--
#
# Total Num images Checked:42767, MAE:12.578209337529362  07/26/2022 18:17:54
# 7 /project/results/soutput3/snapshots/epoch_7.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:17:55--
#
# Total Num images Checked:42767, MAE:13.846451690395876  07/26/2022 18:19:22
# 8 /project/results/soutput3/snapshots/epoch_8.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:19:22--
#
# Total Num images Checked:42767, MAE:13.329984041568139  07/26/2022 18:20:51
# 9 /project/results/soutput3/snapshots/epoch_9.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:20:51--
#
# Total Num images Checked:42767, MAE:12.114514954135021  07/26/2022 18:22:18
# 10 /project/results/soutput3/snapshots/epoch_10.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:22:18--
#
# Total Num images Checked:42767, MAE:14.063611497081963  07/26/2022 18:25:11
# 12 /project/results/soutput3/snapshots/epoch_12.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:25:11--
#
# Total Num images Checked:42767, MAE:13.101287265734218  07/26/2022 18:26:38
# 13 /project/results/soutput3/snapshots/epoch_13.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:26:39--
#
# Total Num images Checked:42767, MAE:13.421058866253398  07/26/2022 18:28:07
# 14 /project/results/soutput3/snapshots/epoch_14.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:28:07--
#
# Total Num images Checked:42767, MAE:14.27810935202625  07/26/2022 18:29:32
# 15 /project/results/soutput3/snapshots/epoch_15.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:29:32--
#
# Total Num images Checked:42767, MAE:13.843977953502092  07/26/2022 18:31:01
# 16 /project/results/soutput3/snapshots/epoch_16.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:31:02--
#
# Total Num images Checked:42767, MAE:14.761773461360125  07/26/2022 18:32:30
# 17 /project/results/soutput3/snapshots/epoch_17.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:32:30--
#
# Total Num images Checked:42767, MAE:13.23258531263947  07/26/2022 18:33:57
# 18 /project/results/soutput3/snapshots/epoch_18.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:33:57--
#
# Total Num images Checked:42767, MAE:14.146049391426669  07/26/2022 18:35:25
# 19 /project/results/soutput3/snapshots/epoch_19.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:35:25--
#
# Total Num images Checked:42767, MAE:13.510697287415564  07/26/2022 18:36:53
# 20 /project/results/soutput3/snapshots/epoch_20.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:36:53--
#
# Total Num images Checked:42767, MAE:14.890025571901363  07/26/2022 18:38:21
# 21 /project/results/soutput3/snapshots/epoch_21.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:38:21--
#
# Total Num images Checked:42767, MAE:13.985027523161438  07/26/2022 18:41:13
# 23 /project/results/soutput3/snapshots/epoch_23.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:41:14--
#
# Total Num images Checked:42767, MAE:13.814289980382569  07/26/2022 18:42:40
# 24 /project/results/soutput3/snapshots/epoch_24.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:42:41--
#
# Total Num images Checked:42767, MAE:14.19789961986691  07/26/2022 18:44:08
# 25 /project/results/soutput3/snapshots/epoch_25.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:44:09--
#
# Total Num images Checked:42767, MAE:14.014208278333097  07/26/2022 18:45:35
# 26 /project/results/soutput3/snapshots/epoch_26.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:45:35--
#
# Total Num images Checked:42767, MAE:13.955551704134157  07/26/2022 18:46:59
# 27 /project/results/soutput3/snapshots/epoch_27.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:47:00--
#
# Total Num images Checked:42767, MAE:14.495233330153251  07/26/2022 18:48:27
# 28 /project/results/soutput3/snapshots/epoch_28.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:48:28--
#
# Total Num images Checked:42767, MAE:13.933333219614413  07/26/2022 18:49:56
# 29 /project/results/soutput3/snapshots/epoch_29.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:49:57--
#
# Total Num images Checked:42767, MAE:14.098522671178644  07/26/2022 18:51:24
# 30 /project/results/soutput3/snapshots/epoch_30.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:51:24--
#
# Total Num images Checked:42767, MAE:13.741381804372585  07/26/2022 18:52:51
# 31 /project/results/soutput3/snapshots/epoch_31.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:52:51--
#
# Total Num images Checked:42767, MAE:14.43665823338318  07/26/2022 18:54:19
# 32 /project/results/soutput3/snapshots/epoch_32.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:54:19--
#
# Total Num images Checked:42767, MAE:13.838402788797113  07/26/2022 18:55:45
# 33 /project/results/soutput3/snapshots/epoch_33.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:55:45--
#
# Total Num images Checked:42767, MAE:14.15420983222703  07/26/2022 18:57:12
# 34 /project/results/soutput3/snapshots/epoch_34.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:57:12--
#
# Total Num images Checked:42767, MAE:14.021858125141856  07/26/2022 18:58:38
# 35 /project/results/soutput3/snapshots/epoch_35.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 18:58:38--
# Total Num images Checked:42767, MAE:14.421304559418765  07/26/2022 19:00:05
# 36 /project/results/soutput3/snapshots/epoch_36.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:00:05--
#
# Total Num images Checked:42767, MAE:14.48090464135083  07/26/2022 19:01:32
# 37 /project/results/soutput3/snapshots/epoch_37.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:01:32--
#
# Total Num images Checked:42767, MAE:13.479720700083613  07/26/2022 19:02:57
# 38 /project/results/soutput3/snapshots/epoch_38.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:02:57--
#
# Total Num images Checked:42767, MAE:14.436187423162046  07/26/2022 19:04:23
# 39 /project/results/soutput3/snapshots/epoch_39.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:04:23--
#
# Total Num images Checked:42767, MAE:14.691065127656007  07/26/2022 19:07:19
# 41 /project/results/soutput3/snapshots/epoch_41.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:07:20--
#
# Total Num images Checked:42767, MAE:14.420202985525416  07/26/2022 19:08:47
# 42 /project/results/soutput3/snapshots/epoch_42.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:08:48--
#
# Total Num images Checked:42767, MAE:14.302514845095839  07/26/2022 19:10:16
# 43 /project/results/soutput3/snapshots/epoch_43.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:10:16--
#
# Total Num images Checked:42767, MAE:14.140989478498515  07/26/2022 19:11:42
# 44 /project/results/soutput3/snapshots/epoch_44.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:11:43--
#
# Total Num images Checked:42767, MAE:14.702695930143262  07/26/2022 19:13:11
# 45 /project/results/soutput3/snapshots/epoch_45.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:13:11--
#
# Total Num images Checked:42767, MAE:14.786019893836189  07/26/2022 19:14:39
# 46 /project/results/soutput3/snapshots/epoch_46.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:14:39--
#
# Total Num images Checked:42767, MAE:14.089986216155923  07/26/2022 19:16:05
# 47 /project/results/soutput3/snapshots/epoch_47.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:16:06--
#
# Total Num images Checked:42767, MAE:14.030081238115942  07/26/2022 19:17:31
# 48 /project/results/soutput3/snapshots/epoch_48.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:17:32--
#
# Total Num images Checked:42767, MAE:14.06067740891258  07/26/2022 19:18:58
# 49 /project/results/soutput3/snapshots/epoch_49.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:18:58--
#
# Total Num images Checked:42767, MAE:14.79135084841354  07/26/2022 19:20:26
# 50 /project/results/soutput3/snapshots/epoch_50.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:20:27--
#
# Total Num images Checked:42767, MAE:14.428250026963667  07/26/2022 19:21:56
# 51 /project/results/soutput3/snapshots/epoch_51.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:21:56--
#
# Total Num images Checked:42767, MAE:14.459281842560806  07/26/2022 19:23:22
# 52 /project/results/soutput3/snapshots/epoch_52.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:23:22--
#
# Total Num images Checked:42767, MAE:14.040442947159375  07/26/2022 19:24:47
# 53 /project/results/soutput3/snapshots/epoch_53.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:24:47--
#
# Total Num images Checked:42767, MAE:14.85961868370777  07/26/2022 19:26:13
# 54 /project/results/soutput3/snapshots/epoch_54.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:26:13--
#
# Total Num images Checked:42767, MAE:14.54087264936103  07/26/2022 19:27:40
# 55 /project/results/soutput3/snapshots/epoch_55.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:27:40--
#
# Total Num images Checked:42767, MAE:14.276501501605665  07/26/2022 19:29:08
# 56 /project/results/soutput3/snapshots/epoch_56.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:29:08--
#
# Total Num images Checked:42767, MAE:14.100332815885137  07/26/2022 19:30:37
# 57 /project/results/soutput3/snapshots/epoch_57.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:30:37--
#
# Total Num images Checked:42767, MAE:14.391028670415043  07/26/2022 19:32:02
# 58 /project/results/soutput3/snapshots/epoch_58.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:32:02--
#
# Total Num images Checked:42767, MAE:14.743687399367222  07/26/2022 19:33:26
# 59 /project/results/soutput3/snapshots/epoch_59.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:33:27--
#
# Total Num images Checked:42767, MAE:14.162858558748129  07/26/2022 19:34:53
# 60 /project/results/soutput3/snapshots/epoch_60.pkl
#
# test configuration: gpu_id=cuda:0, batch_size=50
# model_arch=ResNet50 Start testing dataset=mpiigaze--07/26/2022 19:34:53--
#
# Total Num images Checked:42767, MAE:14.691552322884872  07/26/2022 19:36:23
