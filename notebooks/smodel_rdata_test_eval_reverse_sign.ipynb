# %%
import os, argparse
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from pytz import timezone
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.utils.data import DataLoader
from torchvision import transforms
import torch.backends.cudnn as cudnn
import torchvision
import wandb

import datasets
# from utils import select_device, natural_keys, gazeto3d, angular, getArch
from utils import select_device, natural_keys, gazeto3d, angular, getArch
from model import L2CS

# %%
wandb.init(project="smode_rdata_reverse_sign")
# Out:
# wandb: Currently logged in as: synthesis-ai (use `wandb login --relogin` to force relogin)
# wandb version 0.12.18 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/project/notebooks/wandb/run-20220618_000915-1hs75e5u</code>
# Syncing run <strong><a href="https://wandb.ai/synthesis-ai/smode_rdata/runs/1hs75e5u" target="_blank">fragrant-water-11</a></strong> to <a href="https://wandb.ai/synthesis-ai/smode_rdata" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/synthesis-ai/smode_rdata/runs/1hs75e5u?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
# check if we have the correct number of checkpoint files 
ppath ='/project/results/soutput/snapshots/' 
for fold in range(15):
    foldstr = f"fold{fold:0>2}"
    cpath =os.path.join(ppath, foldstr)
    files = os.listdir(cpath)
    print(len(files), end=" ")
# Out:
# 61 61 61 61 61 61 61 61 61 61 61 61 61 61 61

# %%
def parse_args():
    """Parse input arguments."""
    parser = argparse.ArgumentParser(
        description='Gaze estimation using L2CSNet .')
     # Gaze360
    parser.add_argument(
        '--gaze360image_dir', dest='gaze360image_dir', help='Directory path for gaze images.',
        default='datasets/Gaze360/Image', type=str)
    parser.add_argument(
        '--gaze360label_dir', dest='gaze360label_dir', help='Directory path for gaze labels.',
        default='datasets/Gaze360/Label/test.label', type=str)
    # mpiigaze
    parser.add_argument(
        '--gazeMpiimage_dir', dest='gazeMpiimage_dir', help='Directory path for gaze images.',
        default='datasets/MPIIFaceGaze/Image', type=str)
    parser.add_argument(
        '--gazeMpiilabel_dir', dest='gazeMpiilabel_dir', help='Directory path for gaze labels.',
        default='datasets/MPIIFaceGaze/Label', type=str)
    # Important args -------------------------------------------------------------------------------------------------------
    # ----------------------------------------------------------------------------------------------------------------------
    parser.add_argument(
        '--dataset', dest='dataset', help='gaze360, mpiigaze',
        default= "gaze360", type=str)
    parser.add_argument(
        '--snapshot', dest='snapshot', help='Path to the folder contains models.', 
        default='output/snapshots/L2CS-gaze360-_loader-180-4-lr', type=str)
    parser.add_argument(
        '--evalpath', dest='evalpath', help='path for the output evaluating gaze test.',
        default="evaluation/L2CS-gaze360-_loader-180-4-lr", type=str)
    parser.add_argument(
        '--gpu',dest='gpu_id', help='GPU device id to use [0]',
        default="0", type=str)
    parser.add_argument(
        '--batch_size', dest='batch_size', help='Batch size.',
        default=100, type=int)
    parser.add_argument(
        '--arch', dest='arch', help='Network architecture, can be: ResNet18, ResNet34, [ResNet50], ''ResNet101, ResNet152, Squeezenet_1_0, Squeezenet_1_1, MobileNetV2',
        default='ResNet50', type=str)
    # ---------------------------------------------------------------------------------------------------------------------
    # Important args ------------------------------------------------------------------------------------------------------
    args = parser.parse_args()
    return args

# %%
args = argparse.Namespace()
args.gazeMpiimage_dir = '/project/data/Image'  #real data 
args.gazeMpiilabel_dir = '/project/data/Label'  #real label
args.output = '/project/results/soutput/snapshots/'
args.dataset = 'mpiigaze'
args.snapshot='/project/results/soutput/snapshots/'
args.evalpath = '/project/results/sroutput/evaluation/'
args.gpu_id = '0,1,2,3'
args.gpu_id = '0'
args.batch_size = 20
args.arch = 'ResNet50'
args.bins=28
args.angle = 180
args.bin_width = 4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 args = argparse.Namespace()
#       2 args.gazeMpiimage_dir = '/project/data/Image'  #real data
#       3 args.gazeMpiilabel_dir = '/project/data/Label'  #real label
#
# NameError: name 'argparse' is not defined

# %%
batch_size=args.batch_size
arch=args.arch
data_set=args.dataset
evalpath =args.evalpath
snapshot_path = args.snapshot
bins=args.bins
angle=args.angle
bin_width=args.bin_width

# %%
# args = parse_args()
cudnn.enabled = True
gpu = select_device(args.gpu_id, batch_size=args.batch_size)
transformations = transforms.Compose([
    transforms.Resize(448),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

model_used=getArch(arch, bins)  #resnet50 and 28 bins

# %%
# fold=2
# folder = os.listdir(os.path.join(snapshot_path, "fold" + f'{fold:0>2}'))
# folder.sort(key=natural_keys)
# folder.pop(-1)  #remove the tensorboard file
# # print(folder)
# epochs = folder[3]
# os.path.join(snapshot_path+"fold"+f'{fold:0>2}', epochs)

# %%
# print(evalpath, snapshot_path)

# %%
# print(data_set)

# %%
# %%time
all_MAE = []
# tosave={}
for fold in range(15):
    print(f"fold={fold}")
    epoch_values=[]
    mae_values=[]


    now = datetime.utcnow()
    now = now.astimezone(timezone('US/Pacific'))
    date_format='%m/%d/%Y %H:%M:%S'
    now = now.strftime(date_format)
    
    print(args.gazeMpiilabel_dir)
    folder = os.listdir(args.gazeMpiilabel_dir)
    folder.sort()  #individual label files
    testlabelpathcombined = [os.path.join(args.gazeMpiilabel_dir, j) for j in folder] 
    
    gaze_dataset=datasets.Mpiigaze(testlabelpathcombined, args.gazeMpiimage_dir, transformations, False, angle, fold)

    test_loader = torch.utils.data.DataLoader(
        dataset=gaze_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=4,
        pin_memory=True)

    fold_path = os.path.join(evalpath, 'fold' + f'{fold:0>2}'+'/')  #for evaluation
#     print(f"fold_path is {fold_path}")
    if not os.path.exists(fold_path):
        os.makedirs(fold_path)

#     if not os.path.exists(os.path.join(evalpath, f"fold"+str(fold))):
#         os.makedirs(os.path.join(evalpath, f"fold"+str(fold)))

    # list all epoch for testing
    folder = os.listdir(os.path.join(snapshot_path, "fold" + f'{fold:0>2}'))
    folder.sort(key=natural_keys)
    folder.pop(-1)  #remove the tensorboard file, now all snapshot files
#     print(f"folder={folder}")
                    

    softmax = nn.Softmax(dim=1)
#     with open(os.path.join(evalpath, os.path.join("fold"+f'{fold:0>2}', data_set+".log")), 'w') as outfile:
        
    configuration = (f"\ntest configuration equal gpu_id={gpu}, batch_size={batch_size}, model_arch={arch}\n"
                     f"Start testing dataset={data_set}, FOLD={fold} --{now}---------")
    print(configuration)
#     tosave['time':now]
#     outfile.write(configuration)
    epoch_list=[]
    avg_MAE=[]
    for epoch in folder: 
        print(f"entering epoch={epoch}")
        model=model_used
        checkpoint = torch.load(os.path.join(snapshot_path+"fold"+f'{fold:0>2}', epoch))
        saved_state_dict = checkpoint['model_state_dict']
        model= nn.DataParallel(model,device_ids=[0])
        model.load_state_dict(saved_state_dict)
        model.cuda(gpu)
        model.eval()
        total = 0
        idx_tensor = [idx for idx in range(28)]
        idx_tensor = torch.FloatTensor(idx_tensor).cuda(gpu)
        avg_error = .0
        with torch.no_grad():
            for j, (images, labels, cont_labels, name) in enumerate(test_loader):
                images = Variable(images).cuda(gpu)
                total += cont_labels.size(0)

                label_pitch = cont_labels[:,0].float()*np.pi/180
                label_yaw = cont_labels[:,1].float()*np.pi/180

                gaze_pitch, gaze_yaw = model(images)

                # Binned predictions
                _, pitch_bpred = torch.max(gaze_pitch.data, 1)
                _, yaw_bpred = torch.max(gaze_yaw.data, 1)

                # Continuous predictions
                pitch_predicted = softmax(gaze_pitch)
                yaw_predicted = softmax(gaze_yaw)

                # mapping from binned (0 to 28) to angels (-42 to 42)                
                pitch_predicted = \
                    torch.sum(pitch_predicted * idx_tensor, 1).cpu() * 3 - 42
                yaw_predicted = \
                    torch.sum(yaw_predicted * idx_tensor, 1).cpu() * 3 - 42

                pitch_predicted = pitch_predicted*np.pi/180
                yaw_predicted = yaw_predicted*np.pi/180

                for p,y,pl,yl in zip(pitch_predicted, yaw_predicted, label_pitch, label_yaw):
                    pl, yl = yl, pl
#                     yl = yl*(-1.0)
                    avg_error += angular(gazeto3d([p,y]), gazeto3d([pl,yl]))

        x = ''.join(filter(lambda i: i.isdigit(), epoch))
#             print(f"x={x}")
        epoch_list.append(x)
        mean_mae = avg_error/total  #mean mae over the 3000 iamges
        avg_MAE.append(mean_mae)  
#             print(f"total={total}")
        
        loger = f"[{epoch}---{args.dataset}] Total Num:{total},MAE:{mean_mae}"
#         outfile.write(loger)
        print(loger)
#             print(f"done epoch={epochs}")
        epochn = int(x)
#         wandb.log({'epoch':epochn,'total':total, 'MAE':mean_mae, 'FOLD':fold })
#         tosave ={'epoch':epochn,'total':total, 'MAE':mean_mae, 'FOLD':fold }
        epoch_values.append(epochn)
        mae_values.append(mean_mae)
# #         wandb.log(tosave)
    all_MAE.append(avg_MAE)
    data = [[x, y] for (x, y) in zip(epoch_values, mae_values)]
    table = wandb.Table(data=data, columns = ["x", "y"])
    wandb.log({"epoch_losses" : wandb.plot.line(table, "x", "y",
               title="Epoch loss for each fold")})
    
#     fig = plt.figure(figsize=(14, 8))        
#     plt.xlabel('epoch')
#     plt.ylabel('avg')
#     plt.title('Gaze angular error')
#     plt.legend()
#     plt.plot(epoch_list, avg_MAE, color='k', label='mae')
#     fig.savefig(os.path.join(evalpath, os.path.join("fold"+f'{fold:0>2}', data_set+".png")), format='png')
#     # plt.show()
# Out:
# fold=0
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
#
# test configuration equal gpu_id=cuda:0, batch_size=20, model_arch=ResNet50
# Start testing dataset=mpiigaze, FOLD=0 --06/17/2022 17:09:19---------
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:13.965764770150047
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:13.310476886626795
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:13.964950913254011
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:13.938010759117999
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:13.047713832480783
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:12.701151995302467
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:12.697705981177707
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:13.714712629553384
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:12.815404264470448
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:13.260283160203166
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:13.941974588568963
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:13.619629835892686
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:12.753899080797739
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:13.238229137907402
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:12.507904497450795
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:13.155326818142015
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:13.586905413066988
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:13.530029523415745
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:13.545754121355968
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:13.503233960094558
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:13.602148554107334
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:13.337056331633404
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:13.112049201512484
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:13.321175511555424
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:13.578643048759924
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:12.86968887509553
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:13.116768373532134
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:13.10894066945392
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:13.159443976889088
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:13.531797274777295
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:13.447194090563137
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:13.915333778288314
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:13.453213715140699
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:13.331104879342858
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:13.37036103544803
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:13.270272054122401
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:13.261426350868188
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:13.141410404790776
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:13.625135125902322
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:13.265272893231941
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:13.415971342278835
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:13.457687206146392
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:13.171170878659352
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:13.326393296095096
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:13.227156377371234
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:13.140135372366693
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:13.72101639538696
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:13.408840206597072
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:14.039260141283703
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:13.680354781340936
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:13.540099748966917
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:13.304932088180443
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:13.611382893841817
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:13.367300005411506
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:13.835514537573635
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:13.331226987042632
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:12.905135498693545
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:13.416237232362073
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:13.110898423215586
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:13.35378135155049
# fold=1
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
#
# test configuration equal gpu_id=cuda:0, batch_size=20, model_arch=ResNet50
# Start testing dataset=mpiigaze, FOLD=1 --06/17/2022 17:25:37---------
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:12.313656857753315
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:11.901546817312642
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:11.14122287590124
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:10.968451740481804
# entering epoch=epoch_5.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:12.3962323467595
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:11.64208936097898
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:11.592712182214079
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:12.60186689943932
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:11.341789359135612
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:11.88098446754794
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:12.26903958034594
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:11.14027426751966
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:11.495029155109119
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:11.993258716236767
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:12.361065083347038
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:12.443422614327647
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:12.21974445347695
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:12.470472909940373
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:12.667021065067502
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:12.525552246106104
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:12.319937061646499
# entering epoch=epoch_30.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:13.661911198221805
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:12.656170323309249
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:12.302184630329823
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:12.833857167732456
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:12.782668427506879
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:12.528315243240835
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:13.528603275960936
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:13.346865133012665
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:13.413585831852672
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:13.614334813142497
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:13.074439279211374
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:14.369535375733742
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:13.312857561623884
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:13.248739523604602
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:13.576089233532421
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:13.210868552863678
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:13.983961196055079
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:12.803160236282022
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:13.71172941442368
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:13.647586232433751
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:14.38494584159206
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:13.974669756394968
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:13.659016595466749
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:14.10375324176634
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:13.118273951535734
# fold=2
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
#
# test configuration equal gpu_id=cuda:0, batch_size=20, model_arch=ResNet50
# Start testing dataset=mpiigaze, FOLD=2 --06/17/2022 17:39:23---------
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:12.206413037405708
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:13.258188177126867
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:13.152447418003934
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:15.342670062386292
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:14.485099743956486
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:13.986011253860545
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:13.738809941633995
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:13.849826452136838
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:14.657175115322607
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:14.832560754995885
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:14.730658848795152
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:15.151914116063049
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:14.280527158927265
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:15.59587677000479
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:14.695546207620453
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:15.62311532571336
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:15.122220684908735
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:15.148893928183552
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:14.901380478392332
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:14.313707656247162
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:14.529277658707816
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:15.487453281049719
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:15.308961816218996
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:15.670246873111225
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:14.193264394930237
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:15.613174286461462
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:15.982126790340434
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:15.244585762835863
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:15.55909330518499
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:15.238589538441595
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:15.832884981144375
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:15.293997021259255
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:14.882155427407726
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:15.019664830478908
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:15.50748562154527
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:15.067949200260518
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:15.102756528494135
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:14.916879175246882
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:15.178708681740929
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:15.538198505904038
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:15.944761456772468
# entering epoch=epoch_42.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:14.801775375171882
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:14.752087879667423
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:15.236306061088635
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:14.605860714857695
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:15.557818243850605
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:14.48460390796605
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:15.2538267801439
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:15.098160520810088
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:14.970694758401075
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:15.378080071679307
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:15.134079797038702
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:15.357914333818439
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:14.567953151026158
# fold=3
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
#
# test configuration equal gpu_id=cuda:0, batch_size=20, model_arch=ResNet50
# Start testing dataset=mpiigaze, FOLD=3 --06/17/2022 17:53:05---------
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:14.19365904469941
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:14.89092182991873
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:14.987873298281544
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:15.089173001624527
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:16.43396279077605
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:15.102110774273429
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:14.98283452591543
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:15.866509204618005
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:16.432752921039125
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:15.87001508084965
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:16.054214682406755
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:16.180795668165977
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:17.19262322626391
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:16.439022927689344
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:15.710511153859722
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:16.642114310352476
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:16.674246731340723
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:16.195755723317045
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:15.20088765381742
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:16.14788538771386
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:15.679065371670417
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:15.816315378120494
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:16.555379644373463
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:16.299692098510658
# entering epoch=epoch_25.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:15.913486455707986
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:16.219600778874995
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:16.55893455294547
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:16.549440608712207
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:16.007951923589626
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:16.01783645436584
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:16.326562595109102
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:15.761405155261277
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:16.13447444518046
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:16.125999417599328
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:15.933019934982683
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:16.598173415377666
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:15.936529420842446
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:16.409961649476127
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:16.490280575504464
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:16.299009421979342
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:16.54666831980572
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:16.235637643443575
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:16.109365469728182
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:16.27026042155085
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:16.419741652634574
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:16.713531953305836
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:16.506067646940817
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:16.699826272982925
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:15.270994475433236
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:16.58173678705127
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:16.181115165999586
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:16.36089733778025
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:15.389459254743763
# fold=4
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
#
# test configuration equal gpu_id=cuda:0, batch_size=20, model_arch=ResNet50
# Start testing dataset=mpiigaze, FOLD=4 --06/17/2022 18:07:24---------
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:9.920093812763135
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:9.861471007121855
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:10.904965647433484
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:10.193754824356997
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:11.06234162636839
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:9.866244072837167
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:9.873031018169199
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:9.72499044321177
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:9.589421669464965
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:9.844716958024582
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:9.923279543972859
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:9.99742086249008
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:9.957436848232602
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:9.847744851757724
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:10.247536608118034
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:10.06625790341882
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:9.945771217254544
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:9.954116512816551
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:9.924609349991075
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:9.860015762077252
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:10.029634684860415
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:10.061160337424004
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:10.744338691955258
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:10.773521976423357
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:10.096364834762815
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:10.716047679394414
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:10.399350498160274
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:10.05388315569492
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:10.61157165810533
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:10.524963090516144
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:10.134299627437578
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:10.455991222666313
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:10.286655545217318
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:10.198727135401482
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:10.56039696345885
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:10.315722830346068
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:10.869316048800222
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:10.612632550620187
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:10.863241278459629
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:11.256608623923999
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:11.745890939487415
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:11.19742392187401
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:10.82202864875227
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:11.17768131897269
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:11.521700821269047
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:11.295800844808488
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:11.618644901698085
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:11.271511730062016
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:11.790277212104202
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:11.408949035936743
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:11.397646834649354
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:11.776231918954913
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:11.364265948897819
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:12.02860218738854
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:11.51496678960123
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:12.2696154609726
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:12.462024608634797
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:11.492200569178767
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:12.026316116184702
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:12.284077200372067
# fold=5
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
#
# test configuration equal gpu_id=cuda:0, batch_size=20, model_arch=ResNet50
# Start testing dataset=mpiigaze, FOLD=5 --06/17/2022 18:21:48---------
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:12.896225222131797
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:13.32577801802036
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:12.846304352699438
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:13.434094562002208
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:12.749766914430444
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:12.99852154232474
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:12.872326236128233
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:13.226746640795112
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:13.188350810349348
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:13.529302729026089
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:13.315193054703823
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:13.11710025549885
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:12.93856743550958
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:13.06050404924318
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:13.001987952044132
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:13.569340009777074
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:13.327584574413423
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:13.257617554183557
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:13.09140877065433
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:13.334996964755478
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:13.646491310006187
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:13.344843803189264
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:13.397204724127638
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:13.264625081239084
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:13.399589264213239
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:13.579932262270955
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:13.102400186645042
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:13.494513120373522
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:13.482708383054467
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:13.550598660829696
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:13.676450839515862
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:13.839422153373537
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:13.759321661928626
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:13.724673993178447
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:13.57638138013452
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:13.679294892811209
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:13.548353878670541
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:14.087720314406189
# entering epoch=epoch_39.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:13.512240887425266
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:13.90684384208776
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:13.765316128544187
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:13.48992449444332
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:13.540116439825658
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:13.361919390690572
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:14.019183231778513
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:13.559114843958179
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:13.77354536021655
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:13.55323559689868
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:13.59169259706259
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:13.153397134888444
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:13.638433732286003
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:13.303637760445298
# fold=6
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
#
# test configuration equal gpu_id=cuda:0, batch_size=20, model_arch=ResNet50
# Start testing dataset=mpiigaze, FOLD=6 --06/17/2022 18:36:11---------
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:16.08042335047567
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:18.57745937462128
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:17.663260546605308
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:18.944636289659144
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:17.637212012367186
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:17.17876587348319
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:18.884270008399337
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:19.98379432247736
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:19.125671291385164
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:18.431870728907654
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:17.52479398477408
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:18.015631883010258
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:18.814522221090545
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:19.179579367117498
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:18.99468395880515
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:19.48466414172325
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:19.652412624911232
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:18.751191762385364
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:19.306575908579603
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:18.91801575131086
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:19.043578459361143
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:18.234151902200434
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:18.80468143817583
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:18.83699370631027
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:18.492965213930898
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:18.927706435863954
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:19.610083029926976
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:18.483583468253677
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:19.12954385044353
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:18.809474133840023
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:18.56725713138374
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:18.962034561884508
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:19.158396739446847
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:18.67542797971293
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:18.490562947655246
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:19.783241348474036
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:18.866537267144487
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:18.952265463737298
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:19.16281958673906
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:19.1752455147756
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:18.890016756626565
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:19.205605144722604
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:18.962534766725923
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:19.25339923335263
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:18.78209659530509
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:18.84939115940294
# entering epoch=epoch_47.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:18.605500158332248
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:19.454957501002397
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:18.832142560527366
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:19.626053893215083
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:18.530289905928512
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:19.308688297357186
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:19.240657926034427
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:18.801815797026872
# fold=7
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
#
# test configuration equal gpu_id=cuda:0, batch_size=20, model_arch=ResNet50
# Start testing dataset=mpiigaze, FOLD=7 --06/17/2022 18:50:32---------
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:11.701558426092102
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:11.320959349833744
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:13.055555310235095
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:12.49989937133559
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:12.915228684669458
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:13.030572695991946
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:13.73869700458364
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:13.854637940124734
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:15.592536990124477
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:13.962183637390304
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:14.855630046892298
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:15.563331182730025
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:14.516710183762616
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:15.152672814939159
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:14.436092634341003
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:14.590438098339044
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:15.458827577848249
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:16.18659836589047
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:14.841143628333949
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:15.383823509290623
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:15.71623647360215
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:15.453584588423391
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:15.968966853301245
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:15.037302366628705
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:16.035048839486223
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:15.570618571009065
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:15.560434858245719
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:15.239337456585508
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:15.814567793278918
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:16.633729805313962
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:15.495482409024914
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:16.40554308420556
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:15.691083429184447
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:16.225898091628363
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:16.63968829141144
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:16.33269295747975
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:16.955215548990026
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:16.624600311921714
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:16.524658596950097
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:16.775447702666682
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:16.33594187456749
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:16.229576392542743
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:16.559732909810524
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:16.15869313518856
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:15.653597419547523
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:15.910180420266796
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:16.273270867343445
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:16.437332578077463
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:16.125665569680407
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:15.632793714228418
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:16.48978895685606
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:16.39782907635966
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:15.693701150906005
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:16.241718796199486
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:16.150276022753093
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:16.251759000888754
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:16.4159729503721
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:15.364603578490579
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:16.080301233860386
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:16.18022121400477
# fold=8
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
#
# test configuration equal gpu_id=cuda:0, batch_size=20, model_arch=ResNet50
# Start testing dataset=mpiigaze, FOLD=8 --06/17/2022 19:05:00---------
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:10.954022148555783
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:11.30404912194096
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:11.89368703437787
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:12.360036624394056
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:12.239262221983102
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:12.298436244851914
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:12.524186008467723
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:12.476249925474947
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:12.790121631825935
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:12.671244104213006
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:12.859664554893987
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:13.202106253206958
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:12.69600090422965
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:13.013730947767362
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:13.709083112239062
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:12.997212660853593
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:13.663755620349935
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:13.963093546690333
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:13.198257964222421
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:12.810557918098535
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:14.137539727938636
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:13.416081780714931
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:12.906299428469412
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:13.62086865075718
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:12.929473038861968
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:13.672810703223693
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:13.667302986894642
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:13.859982099055177
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:13.559314143130704
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:13.520612510903062
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:13.536234385470115
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:13.967053089411085
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:13.325851741865387
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:13.638361444741504
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:13.862296269514113
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:13.80286783410981
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:13.87833342892931
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:13.932734707915321
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:14.359070348037836
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:13.554474874677588
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:13.745205684250912
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:13.922077039790015
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:13.688208087472672
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:13.829781734817809
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:13.626198131892206
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:14.34677219764522
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:14.392168867337064
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:14.101224822770892
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:13.986615942915776
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:14.399989367619286
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:14.771328018650289
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:14.429561441770106
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:14.3066560586279
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:14.516049136536424
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:14.683908874637467
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:14.952086995069655
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:14.651159187113201
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:15.371799699234003
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:14.824817235726835
# entering epoch=epoch_60.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:11.128504542851923
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:11.223071720138982
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:11.928570003691487
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:11.675110606186491
# entering epoch=epoch_11.pkl
# ...
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:15.634677898807418
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:17.74680270967905
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:15.39916988405386
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:16.24718414358326
# entering epoch=epoch_9.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:16.5415008722153
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:15.490785051714122
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:16.299722413976763
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:17.48248492908664
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:16.676853187907856
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:17.215034002645524
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:16.440333601240415
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:16.655559716748776
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:16.179043399150526
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:15.885619365807502
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:16.912975087057198
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:17.90155939687239
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:16.47793828199782
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:16.910246645940447
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:16.880533013973967
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:16.672270632635218
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:17.241671748437835
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:16.871312707472505
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:16.134313042488984
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:17.006596116462656
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:15.534863397414032
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:16.055121249559104
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:16.662614411436756
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:16.164133434800714
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:16.699619493090104
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:16.513958718969942
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:17.183799454131815
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:16.80887357199948
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:17.00301173394433
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:16.154422575804738
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:17.573624236771987
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:16.166261824789537
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:16.5159660857
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:17.375582322104034
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:17.453548690274825
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:16.425911157173328
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:17.47573484550906
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:17.17873166579684
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:16.798652586145487
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:17.400368800656913
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:17.044866783969276
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:17.344436096055475
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:17.147890717677043
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:17.14585445385123
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:17.57307988421844
# fold=13
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
#
# test configuration equal gpu_id=cuda:0, batch_size=20, model_arch=ResNet50
# Start testing dataset=mpiigaze, FOLD=13 --06/17/2022 20:17:17---------
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:11.10332914845439
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:12.027709468396337
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:12.055008106365506
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:12.472338344167381
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:11.14111707376403
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:11.406657086240404
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:11.470589459958411
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:12.357909917498885
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:12.163530057359203
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:12.573283322237142
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:11.98997890245222
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:13.240626295666766
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:11.68138605032096
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:12.13019627554008
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:13.72892611494227
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:12.115758079636658
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:11.881493260612112
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:12.41209583244445
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:12.363754177560297
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:11.625622236426576
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:11.938123917828838
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:12.039658867540325
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:11.952985266255194
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:11.855659166048616
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:12.151185357630968
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:12.088971179757865
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:11.840321320344309
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:11.788675363067243
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:12.3651293152919
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:12.59939417341974
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:12.05963170331701
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:12.367818851796049
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:12.053536254078736
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:11.918096601996044
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:12.146953974287918
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:12.058964339161664
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:11.852854214160034
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:11.647884095346576
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:11.751535927494437
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:12.08008916538679
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:11.79214473686713
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:11.7887695504915
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:12.105213416643254
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:11.85769769822455
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:12.00458964008193
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:11.90834246069254
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:12.126370115847434
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:11.954865682323636
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:12.174281918596648
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:12.278553694639179
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:11.396577891609253
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:11.696687837565555
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:12.030621096195963
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:11.850421731219573
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:12.360889633807073
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:12.31475191899633
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:12.240898501226186
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:12.867751412885303
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:12.17703286137311
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:12.67179758749726
# fold=14
# /project/data/Label
# 0 items removed from dataset that have an angle > 180
#
# test configuration equal gpu_id=cuda:0, batch_size=20, model_arch=ResNet50
# Start testing dataset=mpiigaze, FOLD=14 --06/17/2022 20:31:42---------
# entering epoch=epoch_1.pkl
# [epoch_1.pkl---mpiigaze] Total Num:3000,MAE:15.788152016217158
# entering epoch=epoch_2.pkl
# [epoch_2.pkl---mpiigaze] Total Num:3000,MAE:14.345456726885473
# entering epoch=epoch_3.pkl
# [epoch_3.pkl---mpiigaze] Total Num:3000,MAE:15.762329746852684
# entering epoch=epoch_4.pkl
# [epoch_4.pkl---mpiigaze] Total Num:3000,MAE:15.864862304226381
# entering epoch=epoch_5.pkl
# [epoch_5.pkl---mpiigaze] Total Num:3000,MAE:16.60083878664962
# entering epoch=epoch_6.pkl
# [epoch_6.pkl---mpiigaze] Total Num:3000,MAE:17.393769591897797
# entering epoch=epoch_7.pkl
# [epoch_7.pkl---mpiigaze] Total Num:3000,MAE:15.359396749798586
# entering epoch=epoch_8.pkl
# [epoch_8.pkl---mpiigaze] Total Num:3000,MAE:16.744807709166697
# entering epoch=epoch_9.pkl
# [epoch_9.pkl---mpiigaze] Total Num:3000,MAE:16.39557869569305
# entering epoch=epoch_10.pkl
# [epoch_10.pkl---mpiigaze] Total Num:3000,MAE:16.94231357521441
# entering epoch=epoch_11.pkl
# [epoch_11.pkl---mpiigaze] Total Num:3000,MAE:16.314846991964664
# entering epoch=epoch_12.pkl
# [epoch_12.pkl---mpiigaze] Total Num:3000,MAE:16.73608532891329
# entering epoch=epoch_13.pkl
# [epoch_13.pkl---mpiigaze] Total Num:3000,MAE:17.13277376029165
# entering epoch=epoch_14.pkl
# [epoch_14.pkl---mpiigaze] Total Num:3000,MAE:16.544510591484833
# entering epoch=epoch_15.pkl
# [epoch_15.pkl---mpiigaze] Total Num:3000,MAE:16.787302277241984
# entering epoch=epoch_16.pkl
# [epoch_16.pkl---mpiigaze] Total Num:3000,MAE:16.883606724138374
# entering epoch=epoch_17.pkl
# [epoch_17.pkl---mpiigaze] Total Num:3000,MAE:16.55770272441199
# entering epoch=epoch_18.pkl
# [epoch_18.pkl---mpiigaze] Total Num:3000,MAE:16.81681235860213
# entering epoch=epoch_19.pkl
# [epoch_19.pkl---mpiigaze] Total Num:3000,MAE:17.463092934324663
# entering epoch=epoch_20.pkl
# [epoch_20.pkl---mpiigaze] Total Num:3000,MAE:16.952845722417752
# entering epoch=epoch_21.pkl
# [epoch_21.pkl---mpiigaze] Total Num:3000,MAE:17.009437372489547
# entering epoch=epoch_22.pkl
# [epoch_22.pkl---mpiigaze] Total Num:3000,MAE:16.9999536185885
# entering epoch=epoch_23.pkl
# [epoch_23.pkl---mpiigaze] Total Num:3000,MAE:17.074135435651378
# entering epoch=epoch_24.pkl
# [epoch_24.pkl---mpiigaze] Total Num:3000,MAE:17.414981911891594
# entering epoch=epoch_25.pkl
# [epoch_25.pkl---mpiigaze] Total Num:3000,MAE:17.06631148677461
# entering epoch=epoch_26.pkl
# [epoch_26.pkl---mpiigaze] Total Num:3000,MAE:16.936909543251613
# entering epoch=epoch_27.pkl
# [epoch_27.pkl---mpiigaze] Total Num:3000,MAE:16.932329875630508
# entering epoch=epoch_28.pkl
# [epoch_28.pkl---mpiigaze] Total Num:3000,MAE:17.309434569986333
# entering epoch=epoch_29.pkl
# [epoch_29.pkl---mpiigaze] Total Num:3000,MAE:17.435623410869447
# entering epoch=epoch_30.pkl
# [epoch_30.pkl---mpiigaze] Total Num:3000,MAE:17.189288898032043
# entering epoch=epoch_31.pkl
# [epoch_31.pkl---mpiigaze] Total Num:3000,MAE:17.375311859074312
# entering epoch=epoch_32.pkl
# [epoch_32.pkl---mpiigaze] Total Num:3000,MAE:17.31730425721963
# entering epoch=epoch_33.pkl
# [epoch_33.pkl---mpiigaze] Total Num:3000,MAE:17.43551211577551
# entering epoch=epoch_34.pkl
# [epoch_34.pkl---mpiigaze] Total Num:3000,MAE:17.403246882633695
# entering epoch=epoch_35.pkl
# [epoch_35.pkl---mpiigaze] Total Num:3000,MAE:17.885260401504766
# entering epoch=epoch_36.pkl
# [epoch_36.pkl---mpiigaze] Total Num:3000,MAE:17.30972732876605
# entering epoch=epoch_37.pkl
# [epoch_37.pkl---mpiigaze] Total Num:3000,MAE:16.86042124362902
# entering epoch=epoch_38.pkl
# [epoch_38.pkl---mpiigaze] Total Num:3000,MAE:17.134359659144074
# entering epoch=epoch_39.pkl
# [epoch_39.pkl---mpiigaze] Total Num:3000,MAE:17.33174606939103
# entering epoch=epoch_40.pkl
# [epoch_40.pkl---mpiigaze] Total Num:3000,MAE:17.062803001830606
# entering epoch=epoch_41.pkl
# [epoch_41.pkl---mpiigaze] Total Num:3000,MAE:16.946418333231378
# entering epoch=epoch_42.pkl
# [epoch_42.pkl---mpiigaze] Total Num:3000,MAE:17.112213646228312
# entering epoch=epoch_43.pkl
# [epoch_43.pkl---mpiigaze] Total Num:3000,MAE:17.088383158672777
# entering epoch=epoch_44.pkl
# [epoch_44.pkl---mpiigaze] Total Num:3000,MAE:16.955643902158126
# entering epoch=epoch_45.pkl
# [epoch_45.pkl---mpiigaze] Total Num:3000,MAE:17.08354869928389
# entering epoch=epoch_46.pkl
# [epoch_46.pkl---mpiigaze] Total Num:3000,MAE:17.091970259724313
# entering epoch=epoch_47.pkl
# [epoch_47.pkl---mpiigaze] Total Num:3000,MAE:16.900392045231115
# entering epoch=epoch_48.pkl
# [epoch_48.pkl---mpiigaze] Total Num:3000,MAE:17.450515401748
# entering epoch=epoch_49.pkl
# [epoch_49.pkl---mpiigaze] Total Num:3000,MAE:17.356657127880823
# entering epoch=epoch_50.pkl
# [epoch_50.pkl---mpiigaze] Total Num:3000,MAE:16.85688973289967
# entering epoch=epoch_51.pkl
# [epoch_51.pkl---mpiigaze] Total Num:3000,MAE:17.02671712225403
# entering epoch=epoch_52.pkl
# [epoch_52.pkl---mpiigaze] Total Num:3000,MAE:17.31198166076879
# entering epoch=epoch_53.pkl
# [epoch_53.pkl---mpiigaze] Total Num:3000,MAE:16.909406866146814
# entering epoch=epoch_54.pkl
# [epoch_54.pkl---mpiigaze] Total Num:3000,MAE:17.783405285311197
# entering epoch=epoch_55.pkl
# [epoch_55.pkl---mpiigaze] Total Num:3000,MAE:17.46261361121827
# entering epoch=epoch_56.pkl
# [epoch_56.pkl---mpiigaze] Total Num:3000,MAE:17.905955483827352
# entering epoch=epoch_57.pkl
# [epoch_57.pkl---mpiigaze] Total Num:3000,MAE:18.004919262540874
# entering epoch=epoch_58.pkl
# [epoch_58.pkl---mpiigaze] Total Num:3000,MAE:17.502305737169316
# entering epoch=epoch_59.pkl
# [epoch_59.pkl---mpiigaze] Total Num:3000,MAE:17.470188106773847
# entering epoch=epoch_60.pkl
# [epoch_60.pkl---mpiigaze] Total Num:3000,MAE:17.5905680531645
# CPU times: user 2h 56min 27s, sys: 1h 9min 30s, total: 4h 5min 57s
# Wall time: 3h 36min 44s

# %%
all_MAE=np.array(all_MAE)

# %%
print(all_MAE.shape)
print(all_MAE.mean(axis=0))
print(all_MAE.mean(axis=1))
print(all_MAE.mean(axis=0).argmin()+1 ,all_MAE.mean(axis=0).min())
# Out:
# (15, 60)
# [12.73320015 12.66976048 13.29805501 13.49525361 13.49816027 13.51472531
#  13.30842204 14.09889858 14.05949045 13.85637639 13.90967756 14.32806288
#  14.10930814 14.10788745 14.14207063 14.32835782 14.23040513 14.34655454
#  14.26615159 14.00458119 14.25726836 14.20687374 14.35447629 14.36525256
#  14.18271497 14.39796341 14.50344808 14.32886481 14.53107158 14.59748938
#  14.40030267 14.69282299 14.43906777 14.34944433 14.60067985 14.61058843
#  14.41827577 14.57232955 14.66060559 14.62001057 14.61284852 14.69078068
#  14.71025778 14.62712429 14.61639218 14.69013644 14.78735022 14.63679245
#  14.85162752 14.73501859 14.60493425 14.88924773 14.64028477 14.7535466
#  14.90905922 14.91213516 14.91818184 14.808922   14.90649021 14.76218099]
# [13.36636655 12.58951346 14.97902285 16.07620969 10.7099251  13.46431787
#  18.8250614  15.43233654 13.56937345 12.01918444 16.02104838 12.47781844
#  16.52140525 12.06828396 16.99469796]
# 2 12.669760482027039
